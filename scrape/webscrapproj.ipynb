# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np

# %%
final=pd.DataFrame()
for j in range(1,11):
    url='https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
    webpage=requests.get(url,headers=headers).text
    
    soup=BeautifulSoup(webpage,'lxml')
    
    company=soup.find_all('div',class_='company-content-wrapper')
    
    name=[]
    rating=[]
    reviews=[]
    ctype=[]
    hq=[]
    how_old=[]
    employees=[]
    for i in company:
        name.append(i.find('h2').text.strip())
        rating.append(i.find('p',class_='rating').text.strip())
        reviews.append(i.find('a',class_='review-count').text.strip())
        ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
        try:
            hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
        except:
            hq.append(np.nan) 
        try:
            how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
        except:
            how_old.append(np.nan)
        try:
            employees.append(i.find_all('p',class_='infoEntity')[3].text.strip())
        except:
            employees.append(np.nan)

    df=pd.DataFrame({'name':name,
           'rating':rating,
           'reviews':reviews,
           'company_type':ctype,
            'Head_Quarters':hq,
           'Company_Age':how_old,
           'No_of_Employee':employees,
        })
final=final.append(df)
# Out:
# C:\Users\yashw\AppData\Local\Temp\ipykernel_1308\2033117705.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df)

# %%
final
# Out:
#                    name rating         reviews       company_type  \
# 0   Statestreet HCL ...    3.3  (1.8k Reviews)            Private
# 1              Lenskart    3.2  (1.8k Reviews)            Private
# 2        Max Healthcare    4.2  (1.8k Reviews)        Partnership
# 3   Tech Mahindra Bu...    3.5  (1.8k Reviews)             Public
# 4               Walmart    4.1  (1.8k Reviews)            Private
# 5        Mankind Pharma    4.2  (1.8k Reviews)            Private
# 6            AGS Health    4.0  (1.8k Reviews)            Private
# 7   Zensar Technolog...    3.8  (1.8k Reviews)             Public
# 8          Square Yards    3.8  (1.8k Reviews)            Private
# 9   Fortis Healthcar...    4.0  (1.8k Reviews)             Public
# 10               Nestle    4.1  (1.8k Reviews)             Public
# 11  Blue Dart Expres...    4.1  (1.8k Reviews)             Public
# 12  Tata Technologie...    3.7  (1.8k Reviews)            Private
# 13       Landmark Group    4.1  (1.7k Reviews)            Private
# 14             Ola Cabs    3.6  (1.7k Reviews)            Private
# 15               Fiserv    3.7  (1.7k Reviews)            Private
# 16  Birla Sun Life I...    4.3  (1.7k Reviews)            Private
# 17        Future Retail    4.3  (1.7k Reviews)             Public
# 18           HDFC Sales    4.0  (1.7k Reviews)            Private
# 19            Lifestyle    4.4  (1.7k Reviews)            Private
# 20     Societe Generale    3.8  (1.7k Reviews)            Private
# 21  I Process Servic...    3.9  (1.7k Reviews)            Private
# 22        IGT Solutions    3.4  (1.7k Reviews)            Private
# 23            BlackBuck    3.9  (1.7k Reviews)            Private
# 24        Eureka Forbes    4.0  (1.7k Reviews)            Private
# 25               Rivigo    3.9  (1.7k Reviews)            Private
